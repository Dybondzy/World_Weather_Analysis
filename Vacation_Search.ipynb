# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
# gmaps.configure(api_key=g_key)
gmaps.configure(api_key=weather_api_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
import random
import matplotlib.pyplot as plt
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
import os

from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model, metrics
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 1. Import the WeatherPy_database.csv file. 
weather_data = "weather_data/WeatherPy_Database.csv"
city_data_df = pd.read_csv(weather_data)

city_data_df.head()
# Out:
#    City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  Karratha  34.4506   40.9171     56.35        64           0
# 1        1  Karratha -26.8241  -65.2226     66.20        88          90
# 2        2  Karratha  66.8333   70.8333     10.18        94         100
# 3        3  Karratha -53.1500  -70.9167     44.60        81           0
# 4        4  Karratha  31.7167 -116.5667     70.00        50           8
#
#    Wind Speed Country
# 0        9.26      SY
# 1        2.15      AR
# 2       21.81      RU
# 3        3.44      CL
# 4        1.99      MX

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 

min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 80

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1         1  Karratha -26.8241  -65.2226     66.20        88          90
# 4         4  Karratha  31.7167 -116.5667     70.00        50           8
# 5         5  Karratha -46.6000  168.3333     63.00        63         100
# 6         6  Karratha -33.6500  115.3333     72.00        77         100
# 11       11  Karratha  15.0584   43.2851     79.74        56           1
# 12       12  Karratha  -3.8004  102.2655     79.05        75         100
# 15       15  Karratha  -0.7393  -90.3518     77.00        95          10
# 17       17  Karratha  34.6391 -120.4579     63.00        55           0
# 18       18  Karratha  19.7297 -155.0900     78.80        65          90
# 19       19  Karratha  28.6585  -17.9182     64.40        72          75
#
#     Wind Speed Country
# 1         2.15      AR
# 4         1.99      MX
# 5         4.00      NZ
# 6         4.00      AU
# 11        5.41      YE
# 12       13.18      ID
# 15        4.00      EC
# 17        5.75      US
# 18        8.05      US
# 19        6.91      ES

# %%
# 4a. Determine if there are any empty rows.
if preferred_cities_df.shape[0] == 0:
    print('DataFrame is empty')
else:
    print('DataFrame is not empty')
# Out:
# DataFrame is not empty

# %%
# check for null space
AddNan_df = preferred_cities_df.replace('', np.nan)
AddNan_df.head()
# Out:
#     City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1         1  Karratha -26.8241  -65.2226     66.20        88          90
# 4         4  Karratha  31.7167 -116.5667     70.00        50           8
# 5         5  Karratha -46.6000  168.3333     63.00        63         100
# 6         6  Karratha -33.6500  115.3333     72.00        77         100
# 11       11  Karratha  15.0584   43.2851     79.74        56           1
#
#     Wind Speed Country
# 1         2.15      AR
# 4         1.99      MX
# 5         4.00      NZ
# 6         4.00      AU
# 11        5.41      YE

# %%
preferred_cities_df.loc[preferred_cities_df.isna().any(axis=1)]
# Out:
#      City_ID      City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 120      120  Karratha -28.5500  16.4333     61.68        97          42
# 167      167  Karratha -18.0607  13.8400     65.41        85          41
# 233      233  Karratha -20.4637  16.6477     61.25        80          85
# 247      247  Karratha -22.1160  14.2845     70.38        73          68
# 369      369  Karratha -22.9575  14.5053     62.60        82          52
# 469      469  Karratha -28.4500  18.7333     69.17        33           0
# 488      488  Karratha -26.6481  15.1594     66.45        61           0
#
#      Wind Speed Country
# 120       13.15     NaN
# 167       10.22     NaN
# 233        7.56     NaN
# 247        6.22     NaN
# 369        6.91     NaN
# 469        7.67     NaN
# 488       13.20     NaN

# %%
AddNan_df.dropna()
# Out:
#      City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1          1  Karratha -26.8241  -65.2226     66.20        88          90
# 4          4  Karratha  31.7167 -116.5667     70.00        50           8
# 5          5  Karratha -46.6000  168.3333     63.00        63         100
# 6          6  Karratha -33.6500  115.3333     72.00        77         100
# 11        11  Karratha  15.0584   43.2851     79.74        56           1
# ..       ...       ...      ...       ...       ...       ...         ...
# 670      670  Karratha  26.6845  -80.6676     73.99        87          97
# 671      671  Karratha  37.4636 -122.4286     77.00        36           1
# 672      672  Karratha -16.8392   36.9856     62.38        96          27
# 675      675  Karratha -25.1667   46.0833     69.80        79          49
# 677      677  Karratha  27.4667   75.6000     78.73        10           0
#
#      Wind Speed Country
# 1          2.15      AR
# 4          1.99      MX
# 5          4.00      NZ
# 6          4.00      AU
# 11         5.41      YE
# ..          ...     ...
# 670        2.80      US
# 671        1.21      US
# 672        3.00      MZ
# 675        9.80      MG
# 677       11.43      IN
#
# [236 rows x 9 columns]

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df=AddNan_df.dropna()

# %%
clean_df
# Out:
#      City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1          1  Karratha -26.8241  -65.2226     66.20        88          90
# 4          4  Karratha  31.7167 -116.5667     70.00        50           8
# 5          5  Karratha -46.6000  168.3333     63.00        63         100
# 6          6  Karratha -33.6500  115.3333     72.00        77         100
# 11        11  Karratha  15.0584   43.2851     79.74        56           1
# ..       ...       ...      ...       ...       ...       ...         ...
# 670      670  Karratha  26.6845  -80.6676     73.99        87          97
# 671      671  Karratha  37.4636 -122.4286     77.00        36           1
# 672      672  Karratha -16.8392   36.9856     62.38        96          27
# 675      675  Karratha -25.1667   46.0833     69.80        79          49
# 677      677  Karratha  27.4667   75.6000     78.73        10           0
#
#      Wind Speed Country
# 1          2.15      AR
# 4          1.99      MX
# 5          4.00      NZ
# 6          4.00      AU
# 11         5.41      YE
# ..          ...     ...
# 670        2.80      US
# 671        1.21      US
# 672        3.00      MZ
# 675        9.80      MG
# 677       11.43      IN
#
# [236 rows x 9 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df=clean_df.copy()

# 5b. Create a new column "Hotel Name"
# hotel_df["Hotel Name"] = ""
hotel_df = clean_df.insert(0, "Hotel Name", "", True)

# %%
clean_df.head()
# Out:
#    Hotel Name  City_ID      City      Lat       Lng  Max Temp  Humidity  \
# 1                    1  Karratha -26.8241  -65.2226     66.20        88
# 4                    4  Karratha  31.7167 -116.5667     70.00        50
# 5                    5  Karratha -46.6000  168.3333     63.00        63
# 6                    6  Karratha -33.6500  115.3333     72.00        77
# 11                  11  Karratha  15.0584   43.2851     79.74        56
#
#     Cloudiness  Wind Speed Country
# 1           90        2.15      AR
# 4            8        1.99      MX
# 5          100        4.00      NZ
# 6          100        4.00      AU
# 11           1        5.41      YE

# %%
hotel_df=clean_df

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]    
    
    # 6c. Get latitude and longitude from DataFrame
    params["location"] = f"{lat},{lng}"

    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
   

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
   
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-a64dfa68ee96> in <module>
#      26
#      27     # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
# ---> 28     hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
#      29
#
# IndexError: list index out of range

# %%
hotel_df.head()
# Out:
#    Hotel Name  City_ID      City      Lat       Lng  Max Temp  Humidity  \
# 1                    1  Karratha -26.8241  -65.2226     66.20        88
# 4                    4  Karratha  31.7167 -116.5667     70.00        50
# 5                    5  Karratha -46.6000  168.3333     63.00        63
# 6                    6  Karratha -33.6500  115.3333     72.00        77
# 11                  11  Karratha  15.0584   43.2851     79.74        56
#
#     Cloudiness  Wind Speed Country
# 1           90        2.15      AR
# 4            8        1.99      MX
# 5          100        4.00      NZ
# 6          100        4.00      AU
# 11           1        5.41      YE

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_clean_df=hotel_df.dropna()

# %%
hotel_clean_df
# Out:
#     Hotel Name  City_ID      City      Lat       Lng  Max Temp  Humidity  \
# 1                     1  Karratha -26.8241  -65.2226     66.20        88
# 4                     4  Karratha  31.7167 -116.5667     70.00        50
# 5                     5  Karratha -46.6000  168.3333     63.00        63
# 6                     6  Karratha -33.6500  115.3333     72.00        77
# 11                   11  Karratha  15.0584   43.2851     79.74        56
# ..         ...      ...       ...      ...       ...       ...       ...
# 670                 670  Karratha  26.6845  -80.6676     73.99        87
# 671                 671  Karratha  37.4636 -122.4286     77.00        36
# 672                 672  Karratha -16.8392   36.9856     62.38        96
# 675                 675  Karratha -25.1667   46.0833     69.80        79
# 677                 677  Karratha  27.4667   75.6000     78.73        10
#
#      Cloudiness  Wind Speed Country
# 1            90        2.15      AR
# 4             8        1.99      MX
# 5           100        4.00      NZ
# 6           100        4.00      AU
# 11            1        5.41      YE
# ..          ...         ...     ...
# 670          97        2.80      US
# 671           1        1.21      US
# 672          27        3.00      MZ
# 675          49        9.80      MG
# 677           0       11.43      IN
#
# [236 rows x 10 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "weather_data/WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
hotel_clean_df.to_csv(output_data_file, index_label="City_ID")
#clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 

# 11b. Display the figure
